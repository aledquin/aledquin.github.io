# %% [markdown]
# # Notes TCL yaml

# %%
# %load_ext tclmagic

#  If the prev line doesnt work  install it using the next line in your unix terminal
#  /depot/Python/Python-3.8.0/bin/pip install -U tcl-magic
#  You can configure it to

# %% [markdown]
# # Init our libraries and packages

# %%
# %%tcl
#
# set SHELLTOOL_LOC "/remote/cad-rep/msip/tools/Shelltools"
# lappend auto_path "$SHELLTOOL_LOC/ddr-utils-lay/dev/lib/tcl"
# lappend auto_path "/depot/tcl8.6.3/lib"
# lappend
# set RealBin [file dirname [file normalize [info script]] ]
# set RealScript [file tail [file normalize [info script]] ]
# set PROGRAM_NAME $RealScript
# set LOGFILE "[pwd]/log-$PROGRAM_NAME.log"
#
# package require Messaging 1.0
# namespace import ::Messaging::*
# package require Misc 1.0
# namespace import ::Misc::*
# Out:
# TclError: wrong # args: should be "lappend varName ?value value ...?"

# %%
# %%tcl
#
# foreach paku [package names] { puts $paku }
# Out:
# rcs
# counter
# logger
# math::rationalfunctions
# tie::std::dsource
# tclDESjr
# math::roman
# P4
# tcl::chan::memchan
# soundex
# interp::delegate::method
# debug
# tcl::chan::null
# page::analysis::peg::reachable
# doctools::msgcat::idx::de
# uri::urn
# ldap
# simulation::random
# pt::tclparam::configuration::nx
# page::reader::treeser
# tie::std::array
# pt::peg
# zipfile::encode
# page::gen::peg::canon
# uevent
# debug::timestamp
# doctools::config
# json::write
# doctools::msgcat
# textutil
# pt::peg::to::peg
# cmdline
# ident
# term::ansi::code::attr
# gv
# doctools::toc::export::json
# grammar::peg::interp
# tcl::chan::random
# tcl::chan::halfpipe
# rest
# doctools::idx::import::docidx
# term::interact::menu
# grammar::peg
# pt::peg::export::container
# page::writer::tree
# doctools::msgcat::idx::en
# pt::peg::container
# grammar::me::tcl
# simulation::montecarlo
# doctools::idx::export::docidx
# grammar::aycock::runtime
# html
# valtype::verhoeff
# uevent::onidle
# S3
# base32
# page::gen::peg::ser
# ip
# textutil::adjust
# SASL
# page::transform::realizable
# pt::cparam::configuration::critcl
# transfer::transmitter
# pop3d
# nameserv::auto
# crc16
# doctools::idx::export::html
# doctools::msgcat::idx::fr
# doctools::toc::import::doctoc
# math::calculus::symdiff
# asn
# textutil::trim
# doctools::paths
# tie::std::growfile
# stringprep::data
# page::writer::hb
# struct::list
# math::decimal
# try
# doctools::toc::export::doctoc
# fileutil::multi::op
# pop3
# dicttool
# transfer::connect
# grammar::fa::dacceptor
# valtype::isbn
# md4
# crc32
# doctools::idx::structure
# fileutil::multi
# page::parse::pegser
# md5
# page::util::peg
# md5crypt
# tcl::randomseed
# page::writer::tpc
# grammar::me::cpu
# tcl::chan::textwindow
# tepam::doc_gen
# Pgtcl
# docstrip::util
# interp
# math::constants
# page::gen::peg::cpkg
# treeql
# page::writer::null
# bench::out::text
# base64
# sqlite3
# struct::matrix
# page::util::norm::lemon
# page::parse::peghb
# blowfish
# doctools::toc::import::json
# jpeg
# term::receive
# tcl::chan::std
# term::ansi::ctrl::unix
# uuencode
# Thread
# map::slippy::fetcher
# tcl::chan::fifo
# struct::tree
# math::statistics
# Tcldot
# pt::peg::to::cparam
# tcltest
# imap4
# valtype::creditcard::visa
# struct::set
# doctools::idx::export::nroff
# logger::utils
# Messaging
# uuid
# doctools::idx::parse
# doctools::toc::parse
# pt::peg::to::container
# pt::peg::interp
# doctools::msgcat::idx::c
# struct::pool
# autoproxy
# httpd::content
# string::token
# report
# comm
# doctools::idx::export::wiki
# htmlparse
# page::gen::peg::mecpu
# cron
# math::complexnumbers
# valtype::creditcard::amex
# base32::core
# math::interpolate
# nameserv::common
# page::util::norm::peg
# math::geometry
# processman
# page::writer::me
# nameserv::server
# tcl::chan::zero
# pt::rde::nx
# pt::rde::oo
# struct::graph::op
# stringprep
# tie::std::log
# Tk
# doctools::idx::import
# javascript
# textutil::repeat
# http
# inifile
# control
# SASL::NTLM
# pt::tclparam::configuration::snit
# valtype::imei
# dtplite
# pt::peg::op
# page::transform::reachable
# doctools::toc::import
# mapproj
# pt::pgen
# switched
# pt::peg::to::tclparam
# page::util::flow
# page::reader::lemon
# Tclpathplan
# stooop
# snit
# struct::stack
# uri
# pt::peg::export::json
# sha256
# doctools::msgcat::toc::de
# tcl::chan::events
# page::reader::ser
# textutil::split
# pt::peg::import
# oo::option
# map::slippy::cache
# page::reader::peg
# struct
# pluginmgr
# math::special
# string::token::shell
# paths
# doctools::toc::export::text
# math::bignum
# tcl::chan::facade
# log
# tcl::chan::variable
# tcl::chan::fifo2
# page::transform::mecpu
# Tcl
# ripemd128
# smtp
# term::ansi::send
# unicode::data
# doctools::tcl::parse
# pt::cparam::configuration::tea
# ftpd
# map::geocode::nominatim
# pt::peg::from::json
# math::fourier
# yaml
# opt
# doctools::msgcat::toc::en
# transfer::copy
# namespacex
# tool::datatype
# bibtex
# doctools::toc::export::nroff
# fileutil::traverse
# doctools
# grammar::me::util
# tiff
# oo::meta
# oauth
# math::calculus
# map::slippy
# throw
# valtype::luhn5
# math::polynomials
# textutil::expander
# term::ansi::code::macros
# tar
# page::config::peg
# grammar::fa::dexec
# odie::processman
# oo::dialect
# nntp
# doctools::msgcat::toc::fr
# valtype::creditcard::discover
# page::gen::peg::hb
# clock::rfc2822
# json
# math
# units
# bench::in
# page::writer::ser
# tcl::chan::cat
# page::writer::peg
# math::fuzzy
# math::linearalgebra
# valtype::luhn
# transfer::data::source
# ripemd160
# pt::peg::import::json
# page::util::quote
# ncgi
# ftp::geturl
# hook
# lambda
# page::reader::hb
# clock::iso8601
# Ttrace
# http::wget
# tcl::chan::string
# pki
# doctools::idx::export::json
# platform
# irc
# valtype::creditcard::mastercard
# term::receive::bind
# doctools::toc::export::html
# valtype::common
# page::compiler::peg::mecpu
# struct::graph
# pt::rde
# page::analysis::peg::minimize
# otp
# multiplexer
# debug::heartbeat
# resolv
# struct::skiplist
# des
# pop3d::udb
# doctools::idx::export
# tclDES
# nmea
# doctools::changelog
# doctools::msgcat::toc::c
# term::send
# char
# term::ansi::code::ctrl
# pop3d::dbox
# doctools::cvs
# doctools::toc::export
# valtype::usnpi
# nameserv
# base32::hex
# aes
# math::numtheory
# page::writer::mecpu
# png
# websocket
# yencode
# term
# pt::pe::op
# oo::util
# struct::disjointset
# pt::peg::to::json
# spf
# picoirc
# pt::peg::export
# zipfile::decode
# page::writer::identity
# pt::pe
# term::ansi::code
# unicode
# smtpd
# rc4
# page::gen::peg::me
# doctools::toc
# interp::delegate::proc
# xsxp
# Markdown
# page::analysis::peg::realizable
# httpd
# doctools::idx::import::json
# textutil::tabify
# time
# msgcat
# doctools::toc::export::wiki
# math::optimize
# wip
# ldapx
# tie
# ftp
# valtype::iban
# Tclx
# huddle::json
# tdbc
# grammar::aycock
# simulation::annealing
# math::bigfloat
# doctools::text
# grammar::aycock::debug
# pt::peg::export::peg
# Tkspline
# doctools::nroff::man_macros
# grammar::fa
# pt::parse::peg
# DA_widgets
# pt::peg::from::peg
# csv
# huddle
# textutil::string
# doctools::toc::structure
# tepam
# tcl::chan::nullzero
# pt::ast
# page::gen::tree::text
# mime
# Expect
# pt::peg::container::peg
# profiler
# text::write
# bench::out::csv
# transfer::receiver
# debug::caller
# fileutil
# fileutil::decode
# grammar::me::cpu::core
# nameserv::cluster
# configuration
# cksum
# logger::appender
# SASL::XGoogleToken
# grammar::me::cpu::gasm
# struct::queue
# pt::util
# cache::async
# ascii85
# transfer::data::destination
# page::parse::lemon
# Misc
# tie::std::file
# sum
# grammar::fa::op
# struct::record
# pt::peg::to::param
# bench
# Gdtclft
# tcl::tommath
# udpcluster
# pt::peg::import::peg
# page::parse::peg
# bee
# SASL::SCRAM
# pt::tclparam::configuration::tcloo
# nettool
# dns
# tie::std::rarray
# page::analysis::peg::emodes
# page::pluginmgr
# BWidget
# valtype::gs1::ean13
# struct::prioqueue
# docstrip
# doctools::idx
# doctools::html
# term::interact::pager
# scgi::app
# transfer::copy::queue
# sha1
# doctools::html::cssdefaults
# tcl::chan::core
# doctools::idx::export::text
# gpx
# math::machineparameters

# %%
# %%tcl
# package require yaml
# package require doctools
# Out:
# '1.4.20'

# %%
# %%tcl
# info body ::tclLog
# Out:
# '\n\tcatch {puts stderr $string}\n    '

# %%
# %%tcl
# info procs doctools::*
# Out:
# '::doctools::Locate ::doctools::ImgDst ::doctools::_format ::doctools::_warnings ::doctools::_destroy ::doctools::new ::doctools::_cget ::doctools::DoctoolsProc ::doctools::Package ::doctools::Read ::doctools::GetIBase ::doctools::_setparam ::doctools::ImgSrc ::doctools::FmtWarning ::doctools::SetupFormatter ::doctools::MapFile ::doctools::GetModule ::doctools::SearchPaths ::doctools::FileOp ::doctools::GetUser ::doctools::GetFile ::doctools::Eval ::doctools::SetupExpander ::doctools::Source ::doctools::GetFormat ::doctools::GetCopyright ::doctools::FmtError ::doctools::Deprecated ::doctools::help ::doctools::_configure ::doctools::Where ::doctools::LookupFormat ::doctools::_parameters ::doctools::ListLevel ::doctools::FileCmd ::doctools::ExpandInclude ::doctools::_img ::doctools::GetFileId ::doctools::GetMainFile ::doctools::_map ::doctools::_search ::doctools::SetupChecker ::doctools::search ::doctools::ImgData'
